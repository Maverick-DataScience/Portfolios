# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
client = pd.read_csv("data/clients.csv")
client
# Out:
#             Id StateAbbr                             ClientUno  \
# 0            1        MS  B731DA7A-A97A-4A2E-BF11-0A126A05AF70
# 1            2        MS  8101DB7C-0CC8-4DE9-9E87-71137269AAD5
# 2            3        GA  DD5F1EFC-8298-457F-BC09-CABBEB57A697
# 3            4        TX  21DC9E3D-D0AA-4B85-88BB-428F5BCF7F13
# 4            5        ID  3782D4F9-9B16-4BC8-ADA3-F85CEE200630
# ...        ...       ...                                   ...
# 331421  331422        VA  03092D03-1202-4C99-8927-838FCA7F2A39
# 331422  331423        VA  C00B3F98-3714-4599-9B33-3879E58D9F87
# 331423  331424        VA  8145DA8C-9B10-4429-A3D1-BFF24D6FA73F
# 331424  331425        VA  816CA3A7-0ED7-4A51-8DCF-C1A3FB07EC02
# 331425  331426        VA  256345E3-BB8A-47E9-A695-09EEEE4D88D2
#
#                      County    StateName  PostalCode          EthnicIdentity  \
# 0                Washington  Mississippi     73179.0                     NaN
# ...

# %%
client.drop('CreatedUtc', axis=1, inplace=True)

# %%
client.drop('PostalCode', axis=1, inplace=True)

# %%
client.to_csv('client.csv', index=False)

# %%
client
# Out:
#             Id StateAbbr                             ClientUno  \
# 0            1        MS  B731DA7A-A97A-4A2E-BF11-0A126A05AF70
# 1            2        MS  8101DB7C-0CC8-4DE9-9E87-71137269AAD5
# 2            3        GA  DD5F1EFC-8298-457F-BC09-CABBEB57A697
# 3            4        TX  21DC9E3D-D0AA-4B85-88BB-428F5BCF7F13
# 4            5        ID  3782D4F9-9B16-4BC8-ADA3-F85CEE200630
# ...        ...       ...                                   ...
# 331421  331422        VA  03092D03-1202-4C99-8927-838FCA7F2A39
# 331422  331423        VA  C00B3F98-3714-4599-9B33-3879E58D9F87
# 331423  331424        VA  8145DA8C-9B10-4429-A3D1-BFF24D6FA73F
# 331424  331425        VA  816CA3A7-0ED7-4A51-8DCF-C1A3FB07EC02
# 331425  331426        VA  256345E3-BB8A-47E9-A695-09EEEE4D88D2
#
#                      County    StateName          EthnicIdentity   Age  \
# 0                Washington  Mississippi                     NaN   NaN
# ...

# %%
print("The number of row is", client.shape[0])
print("The number of column is", client.shape[1])
# Out:
# The number of row is 331426
# The number of column is 19

# %%
client.StateAbbr.unique()
# Out:
# array(['MS', 'GA', 'TX', 'ID', 'CT', 'VT', 'WY', 'NY', 'AR', 'KS', 'HI',
#        'SD', 'TN', 'MI', 'AK', 'AL', 'LA', 'MD', 'PA', 'IA', 'IL', 'OK',
#        'MO', 'AZ', 'VA', 'CA', 'ME', 'NE', 'NH', 'US', 'NJ', 'MA', 'NM',
#        'UT', 'SC', 'WI', 'IN', 'WV', 'FL', 'NC'], dtype=object)

# %%
clients = client.groupby('StateAbbr').ClientUno.count().reset_index()
clients = clients.rename(columns={'StateAbbr':'State Name'})
clients

sns.set_style('whitegrid')
sns.barplot(x='State Name', y='ClientUno', data=clients)
plt.title('Title of the plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

#state has the highest question asked
#what category is the highest asked in each state

# %%
client.isnull().sum()
# Out:
# Id                         0
# StateAbbr                  0
# ClientUno                  0
# County                   246
# StateName                  0
# PostalCode             17269
# EthnicIdentity         53128
# Age                    51556
# Gender                 51199
# MaritalStatus          51878
# Veteran                61669
# Imprisoned             50824
# NumberInHousehold      50824
# AnnualIncome           50861
# AllowedIncome          50824
# CheckingBalance       119406
# SavingsBalance        225133
# InvestmentsBalance    318264
# CreatedUtc                 0
# dtype: int64

# %%
sns.set_style('whitegrid')
sns.barplot(x='Age', y='County', data=client)
plt.title('Title of the plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
from datetime import datetime

# Define a function to convert dates to a consistent format
def clean_date(date_string):
    # Define the possible date formats
    formats = ['%Y-%m-%d', '%Y/%m/%d','%m/%d/%Y', '%m-%d-%Y','%Y-%m-%d %H:%M:%S', '%Y/%m/%d %H:%M:%S','%m-%d-%Y %H:%M:%S', '%m/%d/%Y %H:%M:%S']
    for fmt in formats:
        try:
            # Try to parse the date using the current format
            dt = datetime.strptime(date_string, fmt)
            # If successful, return the date in a consistent format
            return dt.strftime('%Y-%m-%d %H:%M:%S')
        except ValueError:
            pass
    # If none of the formats work, return NaN
    return pd.NaT

# Apply the function to the date column
client['date'] = df['date'].apply(clean_date)

# Print the cleaned dataframe
print(df)

# %%
questions = pd.read_csv("data/questions.csv")
questions
# Out:
#             Id StateAbbr                           QuestionUno  \
# 0            1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1            2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2            3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3            4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4            5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
# ...        ...       ...                                   ...
# 202874  202875        NC  376FFF48-9068-4A8F-9316-2EB5A7E38001
# 202875  202876        NC  98AA49B1-D423-4D12-9E70-A5BD6663DFE5
# 202876  202877        NC  B80305AA-7509-436E-AFF8-6B33AC682730
# 202877  202878        NC  DC374484-7C6E-44A3-9DB7-89B8868518F1
# 202878  202879        NC  1F2F2FC1-4661-4A14-A7BE-43E883D1BD44
#
#                                  CategoryUno                      Category  \
# 0       C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# ...

# %%
questions.isnull().sum()
# Out:
# Id                          0
# StateAbbr                   0
# QuestionUno                 0
# CategoryUno                 0
# Category                    0
# SubcategoryUno              0
# Subcategory                 0
# AskedByClientUno           38
# AskedOnUtc                  0
# TakenByAttorneyUno      58874
# TakenOnUtc              57228
# ClosedByAttorneyUno     65092
# ClosedOnUtc              3794
# LegalDeadline          158935
# dtype: int64

# %%
()
