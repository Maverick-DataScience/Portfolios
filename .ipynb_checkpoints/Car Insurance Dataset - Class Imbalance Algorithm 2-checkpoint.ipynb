# %% [markdown]
# <h1 style="font-family: 'Georgia'; font-size: 42px;">
#     Fundamental Issues in Insurance Claim Prediction – A Classical Imbalance Problem
# </h1>

# %%
from IPython.core.display import HTML

# Define custom styles for the notebook
HTML('''
<style>
    p {
        font-family: 'Arial' ,sans-serif;
        font-size: 18px;
        line-height: 1.5;
    }
    h1 {
        font-family: 'Arial';
        font-size: 24px;
    }
</style>
''')
# Out:
# <style>
#     p {
#         font-family: 'Arial' ,sans-serif;
#         font-size: 18px;
#         line-height: 1.5;
#     }
#     h1 {
#         font-family: 'Arial';
#         font-size: 24px;
#     }
# </style>

# %% [markdown]
# # Author's Note
# <p style="font-family: 'Arial'; font-size: 18px; line-height: 1.5;">
# This article is designed for both students and anyone interested in understanding practical data science methods. <b>If you're short on time, jump to the Results (3-minute read) for a concise overview of the best-performing models and insights. </b>
#
# The author acknowledges the following:
# * This is an exploratory model.
# * The limitations of the data (e.g., lack of historical or behavioral data).
# * Real-world claim prediction involves richer datasets and more sophisticated method (historical driving behavior, claim history, accident rates, etc.)
#
# The goal of this report is to showcase the current weaknesses and trade-offs of using machine learning for insurance claim prediction in an accessible and straightforward way. For those interested in more advanced, high-accuracy methods, please feel free to explore the <b>"Reading Reference"</b> section, which includes literature discussing more recent and intricate methodologies.
#
# For those diving deeper, I hope this article provides valuable insights to support your learning journey. Thank you for your interest, and I welcome any feedback, suggestions, or ideas for improvement. Feel free to reach out at maverick.article@gmail.com.
# </p>

# %% [markdown]
# # Overview (3-minute read)

# %% [markdown]
# <p style="font-family: 'Arial', sans-serif; font-size: 18px; line-height: 1.5;">
#      In recent years, the insurance industry has been making a significant shift toward artificial intelligence (AI). Faced with increasing data availability and rising competition, companies are eager to leverage AI’s ability to analyze vast datasets to uncover patterns that human analysts might miss and for efficiency.
#
# However, transitioning to AI-driven systems is not without its challenges. Take claim prediction, for example—a task that seems straightforward on the surface but quickly becomes a data scientist’s nightmare. In the world of insurance, claims are rarely made, and for many policyholders, they may never be made at all. The chances of a claim occurring are near zero. This fundamental challenge of insurance claims makes it difficult for insurance companies to create an algorithm to predict the likelihood of an individual to make a claim or not.
#     <br></br>
#     This scenario suffers from what is known as classification imbalance (CI), where there is not enough information in certain classes for machine learning algorithms to effectively predict outcomes. Where there is insufficient data in certain classes, the algorithm's performance would suffer. To give an example, assuming the actual insurance claims are only 2% of all premiums, we could have just written down this code:
# </p>

# %% [markdown]
# ```{python}
# claims="no insurance claims"
# claims
# ```

# %% [markdown]
# <p style="font-family: 'Arial', sans-serif; font-size: 18px; line-height: 1.7;">
# And just like that, we would achieve a  data scientist's dream- a model boasting 98% accuracy. A very impressive result, right? I would have receive call from all insurance company CEO, each eager to bring that "magic" into their company.
#
# But here’s the reality check: while this model might look great on paper, it’s practically useless. High accuracy masks deeper issues, such as failing to identify the rare but critical instances of actual claims. In reality, this approach sacrifices insight for metrics, creating headaches for implementation teams and leaving insurers no closer to meaningful predictions.
#
# Recent events have shown how these flaws can have significant consequences. UnitedHealthcare, one of the largest healthcare insurers in the U.S., has come under scrutiny for its use of an AI-based system which reportedly denied 33% of claims—even after appeals.[See this news article for details.](https://www.npr.org/2024/12/10/nx-s1-5223471/theres-anger-behind-the-internets-reactions-to-the-death-of-unitedhealthcare-ceo) This controversy highlights the risks of relying on AI in high-stakes scenarios, where fairness, bias, and ethical considerations are just as important as the numbers.
#
# The lesson? Even the most sophisticated models are only as good as the context in which they’re applied.
#
#     In this article, I will introduce more-or-less the complexities of claim prediction, using it as a case study to explore the challenges of AI in imbalanced datasets. From classification trade-offs to real-world implications, we’ll uncover the potential and pitfalls of using machine learning in this critical domain.
#
# </p>
#
# ### Reading Reference (Algorithm and AI in healthcare article)
# * [IAG on creating ethical artificial](https://www.industry.gov.au/news/australian-ai-ethics-principles-insurance-australia-group-reviews-its-ai-claim-decisions)
# * [A survey on single and multiecnomics data mining methods in cancer data classification](https://www.sciencedirect.com/science/article/pii/S1532046420300939)
# * [A comprehensive review of object detection with deep learning](https://www.sciencedirect.com/science/article/pii/S1051200422004298)
# * [Learning From Imbalance Data](https://www.researchgate.net/publication/224541268_Learning_from_Imbalanced_Data)
# * [Classification with class imbalance problem: A review](https://www.researchgate.net/publication/288228469_Classification_with_class_imbalance_problem_A_review)
# * [Frank Harrell: Classification vs. Prediction](https://www.fharrell.com/post/classification/)
# * [PRO-SMOTEBoost: An adaptive SMOTEBoost probabilistic algorithm for rebalancing and improving imbalanced data classification](https://www.sciencedirect.com/science/article/pii/S0020025524014622#:~:text=SMOTEBoost%20rebalances%20many%20highly%20and,changing%20the%20update%20weights%20and)
# * [Improving k Nearest Neighbor with Exemplar Generalization for Imbalanced Classification](https://link.springer.com/chapter/10.1007/978-3-642-20847-8_27).

# %% [markdown]
# <h1 style="font-size: 40px;">Dataset (1min)</h1>

# %% [markdown]
# The dataset for car insurance model is collected from [statso.io](https://statso.io/car-insurance-modelling-case-study/) . Below is the feature and the description of the feature:

# %% [markdown]
# | Feature                                                                                       | Description                                                                                                                                                                      |
# |-----------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | policy_id                                                                                     | Unique identifier for the insurance policy.                                                                                                                                      |
# | subscription_length                                                                           | The duration for which the insurance policy is active.                                                                                                                           |
# | customer_age                                                                                  | Age of the insurance policyholder, which can influence the likelihood of claims.                                                                                                 |
# | vehicle_age                                                                                   | Age of the vehicle insured, which may affect the probability of claims due to factors like wear and tear.                                                                        |
# | segment | Segment of the vehicle|
# |transmission_type | Type of transmission |
# |steering_type | Type of steering mechanism |
# |ncap_rating | NCAP safety rating of the vehicle |
# | model                                                                                         | The model of the vehicle, which could impact the claim frequency due to model-specific characteristics.                                                                          |
# | fuel_type                                                                                     | Type of fuel the vehicle uses (e.g., Petrol, Diesel, CNG), which might influence the risk profile and claim likelihood.                                                          |
# | max_torque, max_power                                                                         | Engine performance characteristics that could relate to the vehicle’s mechanical condition and claim risks.                                                                      |
# | engine_type                                                                                   | The type of engine, which might have implications for maintenance and claim rates.                                                                                               |
# | displacement, cylinder                                                                        | Specifications related to the engine size and construction, affecting the vehicle’s performance and potentially its claim history.                                               |
# | region_code                                                                                   | The code representing the geographical region of the policyholder, as claim patterns can vary regionally.                                                                        |
# | region_density                                                                                | Population density of the policyholder’s region, which could correlate with accident and claim frequencies.                                                                      |
# | airbags                                                                                       | The number of airbags in the vehicle, indicating safety level which can influence claim probability.                                                                             |
# | is_esc (Electronic Stability Control), is_adjustable_steering, is_tpms (Tire Pressure Monitoring System) | Features that enhance vehicle safety and could potentially reduce the likelihood of claims.                                                                  |
# | is_parking_sensors, is_parking_camera                                                         | Parking aids that might affect the probability of making a claim, especially in urban areas.                                                                                     |
# | rear_brakes_type                                                                              | Type of rear brakes, which could be related to the vehicle’s stopping capability and safety.                                                                                     |
# | Various binary indicators (Yes/No) for specific vehicle amenities and safety features         | Features like steering_type, turning_radius, length, width, gross_weight, etc., which together build a profile of the vehicle’s characteristics and its associated risk factors. |
# | claim_status   | Indicates whether a claim was made (1) or not (0), which is the dependent variable the model aims to predict.|

# %%
import pandas as pd

file_path = 'DATA SCIENCE/Insurance claims data.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    policy_id  subscription_length  vehicle_age  customer_age region_code  \
# 0  POL045360                  9.3          1.2            41          C8
# 1  POL016745                  8.2          1.8            35          C2
# 2  POL007194                  9.5          0.2            44          C8
# 3  POL018146                  5.2          0.4            44         C10
# 4  POL049011                 10.1          1.0            56         C13
#
#    region_density segment model fuel_type     max_torque  ... is_brake_assist  \
# 0            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 1           27003      C1    M9    Diesel  200Nm@1750rpm  ...              No
# 2            8794      C2    M4    Diesel  250Nm@2750rpm  ...             Yes
# 3           73430       A    M1       CNG   60Nm@3500rpm  ...              No
# 4            5410      B2    M5    Diesel  200Nm@3000rpm  ...              No
#
#   is_power_door_locks  is_central_locking is_power_steering  \
# 0                 Yes                 Yes               Yes
# 1                 Yes                 Yes               Yes
# 2                 Yes                 Yes               Yes
# 3                  No                  No               Yes
# 4                 Yes                 Yes               Yes
#
#   is_driver_seat_height_adjustable is_day_night_rear_view_mirror is_ecw  \
# 0                              Yes                            No    Yes
# 1                              Yes                           Yes    Yes
# 2                              Yes                            No    Yes
# 3                               No                            No     No
# 4                               No                            No    Yes
#
#   is_speed_alert ncap_rating  claim_status
# 0            Yes           3             0
# 1            Yes           4             0
# 2            Yes           3             0
# 3            Yes           0             0
# 4            Yes           5             0
#
# [5 rows x 41 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58592 non-null  object
#  1   subscription_length               58592 non-null  float64
#  2   vehicle_age                       58592 non-null  float64
#  3   customer_age                      58592 non-null  int64
#  4   region_code                       58592 non-null  object
#  5   region_density                    58592 non-null  int64
#  6   segment                           58592 non-null  object
#  7   model                             58592 non-null  object
#  8   fuel_type                         58592 non-null  object
#  9   max_torque                        58592 non-null  object
#  10  max_power                         58592 non-null  object
#  11  engine_type                       58592 non-null  object
#  12  airbags                           58592 non-null  int64
#  13  is_esc                            58592 non-null  object
#  14  is_adjustable_steering            58592 non-null  object
#  15  is_tpms                           58592 non-null  object
#  16  is_parking_sensors                58592 non-null  object
#  17  is_parking_camera                 58592 non-null  object
#  18  rear_brakes_type                  58592 non-null  object
#  19  displacement                      58592 non-null  int64
#  20  cylinder                          58592 non-null  int64
#  21  transmission_type                 58592 non-null  object
#  22  steering_type                     58592 non-null  object
#  23  turning_radius                    58592 non-null  float64
#  24  length                            58592 non-null  int64
#  25  width                             58592 non-null  int64
#  26  gross_weight                      58592 non-null  int64
#  27  is_front_fog_lights               58592 non-null  object
#  28  is_rear_window_wiper              58592 non-null  object
#  29  is_rear_window_washer             58592 non-null  object
#  30  is_rear_window_defogger           58592 non-null  object
#  31  is_brake_assist                   58592 non-null  object
#  32  is_power_door_locks               58592 non-null  object
#  33  is_central_locking                58592 non-null  object
#  34  is_power_steering                 58592 non-null  object
#  35  is_driver_seat_height_adjustable  58592 non-null  object
#  36  is_day_night_rear_view_mirror     58592 non-null  object
#  37  is_ecw                            58592 non-null  object
#  38  is_speed_alert                    58592 non-null  object
#  39  ncap_rating                       58592 non-null  int64
#  40  claim_status                      58592 non-null  int64
# dtypes: float64(3), int64(10), object(28)
# memory usage: 18.3+ MB

# %% [markdown]
# ## Data Information:

# %% [markdown]
# 1.The dataset contains 58,592 entries with 41 columns
#
# 2.There is a mix of binary, numerical, and categorical variable
#
# 3.The claim_status is the target variable, which is the variable we want to be able to predict whether the claim was made (1) or not made (0).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

ax = sns.countplot(y='claim_status', data=data, hue='claim_status', palette=['lightblue', 'orange'], legend=False)
ax.xaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True) 
total = len(data)
for bar in ax.patches:
    count = bar.get_width()
    percentage = 100 * count / total
    ax.text(count + (total * 0.005), bar.get_y() + bar.get_height() / 2, 
            f'{int(count)} ({percentage:.1f}%)', 
            va='center', fontsize=12, color='black', weight='bold')  # Dark text for visibility

for bar in ax.patches:
    bar.set_edgecolor('black') 
    bar.set_linewidth(1.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="font-size: 42px;">Method (15min)</h1>
#
# Most machine learning algorithms assume balanced data. In an imbalanced dataset, they tend to favor the majority class, leading to:
# - **High overall accuracy but poor performance on the minority class**
#
# - **Missed opportunities to flag rare but critical instances like claims**
#
# To address these challenges, we use two broad approaches: data-level techniques and algorithm-level techniques.
#
# # **Data-Level Approach**
#
# ## A. SMOTE (Synthetic Minority Over-sampling Technique)
#
# According to this [paper](https://www.researchgate.net/publication/288228469_Classification_with_class_imbalance_problem_A_review), SMOTE offers advantages over basic sampling techniques (like over-sampling and down-sampling):
#
# - **Increased Diversity**: SMOTE balances the class distribution while adding variety to the training data, leading to better generalization of the model.
#
# - **Preventing Overfitting**: Unlike random oversampling, which duplicates examples, SMOTE generates synthetic, slightly different variations of the minority class. This reduces the risk of overfitting and ensures the model doesn't memorize specific instances.
# <br></br>
# However, because SMOTE generates synthetic data that might not perfectly reflect real-world variations, it’s important to use it with caution. While it can be effective, SMOTE’s generated samples may sometimes introduce data points that don’t fully capture the <b>true</b> characteristics of the minority class -— essentially creating “virtual” data that lacks the depth of true minority instances. However, for the sake of this report I would try to incorporate SMOTE
#
# <p align="center">
#     <img src="https://miro.medium.com/v2/resize:fit:1400/1*CeOd_Wbn7O6kpjSTKTIUog.png" alt="SMOTE Example" style="width:50%; display: block; margin: 0 auto;">
# </p>
#
# ## B. Combining Downsampling and Upweighting
#
# According to [Google's Datasets: Imbalanced Datasets](https://developers.google.com/machine-learning/crash-course/overfitting/imbalanced-datasets), an effective method is to downsample the majority class and then upweight these downwsampled examples in that downsampled majority class. This process ensures:
#
# - **Balancing Influence**: Even though fewer examples from the majority class are used, they carry more weight during training, maintaining the overall balance between classes.
#
# - **Reduced Bias**: Upweighting the majority class after downsampling helps reduce prediction bias. This ensures the model's predictions reflect the true distribution of the dataset, avoiding an overemphasis on the minority class.
#
# <p align="center">
#     <img src="https://developers.google.com/static/machine-learning/data-prep/images/downsampling-upweighting-v5.svg" alt="Downsampling Upweighting" style="width:50%; display: block; margin: 0 auto;">
# </p>
#
# ## C. Feature Selection
# Feature Selection is a method that involves identifying and retaining only the most relevant features for model training. This process reduces the dataset’s dimensionality, which can improve model performance, interpretability, and training efficiency. In the context of class imbalance, feature selection helps by focusing the model on features that provide the most effect for the minority class.
#
# <p align="center">
#     <img src="feature_selection.png" alt="Downsampling Upweighting" style="width:50%; display: block; margin: 0 auto;">
# </p>

# %% [markdown]
# # **Algorithm-Level Approach**
# With the dataset adjusted, we can now train models capable of handling class imbalance and making predictions. These models use class weights and other parameters to prioritize rare events.
# ## A. Standard Algorithm
# ### 1. Logistic Regression with Class Weights
# Logistic Regression is a classic, interpretable algorithm that remains effective even with class imbalance by applying class weights. By assigning a higher weight to the minority class, we can ensure it doesn’t get lost in the majority.
#
# ```{python}
# PYTHON code
# from sklearn.linear_model import LogisticRegression
#
# lr = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
# lr.fit(X_train, y_train)
# ```
#
# ### 2. Random Forest with Class Weights
# An ensemble of decision trees that prioritizes minority class samples when class weights are adjusted
#
# ```{python}
# PYTHON Code
# from sklearn.ensemble import RandomForestClassifier
#
# rf = RandomForestClassifier(class_weight='balanced', random_state=42)
# rf.fit(X_train, y_train)
# ```
#
# ### 3. Gradient Boosting with scale_pos_weight (XGBoost)
# XGBoost assigns higher importance to the minority class with the scale_pos_weight parameter, making it a go-to for imbalanced datasets.
#
# ```{python}
# PYTHON Code
# from xgboost import XGBClassifier
#
# ratio = len(y_train[y_train == 0]) / len(y_train[y_train == 1])
# xgb = XGBClassifier(scale_pos_weight=ratio, random_state=42)
# xgb.fit(X_train, y_train)
# ```
#
# ### 4. CatBoost with Class Weights
# CatBoost’s class weighting makes it effective on imbalanced data, especially with categorical features, and is often faster than other boosting methods.
#
# ```{python}
# PYTHON CODE
# from catboost import CatBoostClassifier
#
# catboost = CatBoostClassifier(class_weights=[1, 10], random_state=42, verbose=0)  # Adjust weights as needed
# catboost.fit(X_train, y_train)
# ```
# <br></br>

# %% [markdown]
# ## The Role of Thresholds in Decision-Making
# Once the models are trained, they don’t just output “claim” or “no claim.” Instead, they provide a probability score for each prediction. This is where thresholds come into play. Threshold is a decision boundary score ranging from 0.0 to 1.0. If the model:
# - predicts a probability above the threshold (e.g. 50%): Flag as **Claim**
#
# - predicts a probability below the threshold: Flag as **No Claim**
#
# So by adjusting this threshold, we can drastically affect the model’s performance. If we lower the threshold we can capture more **Claim** (high recall) but with more false positives (low precision). Or if we increase the threshold we reduce false positive (high precision) but miss a genuine claim (low recall).
#
# This trade-off highlights the risks of improper calibration, as seen in the recent controversy surrounding UnitedHealthcare. Their AI system faced backlash for allegedly denying 33% of claims, with reports suggesting a 90% error rate.
#
# ## Performance Measure
# To evaluate the effectiveness of these methods, we use the following metrics:
#
# - **Precision**: Indicates the accuracy of positive predictions.
# - **Recall**: Measures the model’s ability to identify positive instances.
# - **F1-Score**: Provides a balance between precision and recall. We will use this parameter for fine-tune the results.
# - **AUC-ROC**: Evaluates the model's ability to distinguish between classes without setting a fixed threshold.
#
# In this study, we prioritize **F1-Score** to balance precision and recall when fine-tuning thresholds. However, other metrics also play a role in understanding the full performance spectrum.

# %% [markdown]
# <h1 style="font-size: 40px;">Selected Method (3min)</h1>
#
# ## Step 1: Apply Feature Selection, Downsampling-Upweighting Technique, SMOTE
# The first step is to address class imbalance. We will create separate dataset using Feature Selection, Downsampling-upweighting Technique, and SMOTE. Feature Selection is chosen to identify the most relevant predictors. Downsampling-Upweighting to balance the dataset while retaining the significance of the majority class. Additionally, SMOTE will be tested to evaluate if synthetic data can improve performance.
#
# ## Step 2: Hybrid and Ensemble Algorithm
# Once the dataset is prepared, the analysis proceeds with more complex algorithms to leverage their advanced capabilities in handling imbalanced data. I will use:
#
# - **Random Forest with Class Weights**
# - **GradientBoosting (XGBoost, LightGBM, CatBoost)**
# - **Stacked Ensemble**
#   Combines the strengths of base models using XGBoost as the meta-model to capture complex interactions and refine predictions further.
#
# ## Step 3:Performance Measure
# To measure the performance for each method, the evaluation will be performed using precision, recall, F1-Score, and AUC-ROC scoring

# %% [markdown]
# <h1 style="font-size: 40px;">Data Processing</h1>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

#categorical variable -> numerical
data_copy = data.drop(columns='policy_id')
for column in data_copy.select_dtypes(include=['object']).columns:
    data_copy[column] = data_copy[column].astype('category').cat.codes

# Check for multicollinearity
parameter = data.select_dtypes(include=['float64', 'int64', 'int8']).drop(columns=['claim_status'], errors='ignore')  # Replace 'target' with your actual target column name
C = parameter.assign(constant=1) #add_constant number

# Calculate VIF for each feature
vif = pd.DataFrame()
vif['Feature'] = parameter.columns
vif['VIF'] = [variance_inflation_factor(C.values, i) for i in range(len(parameter.columns))]

print("Variance Inflation Factor (VIF):")
print(vif)
# Out:
# Variance Inflation Factor (VIF):
#                 Feature         VIF
# 0   subscription_length    1.096785
# 1           vehicle_age    1.268972
# 2          customer_age    1.035697
# 3        region_density    1.018128
# 4               airbags   59.093994
# 5          displacement  484.932490
# 6              cylinder  120.219296
# 7        turning_radius   49.085512
# 8                length  211.888044
# 9                 width   78.916190
# 10         gross_weight    5.434650
# 11          ncap_rating  169.535662

# %%
# Check for multicollinearity
correlation_matrix = parameter.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

threshold = 0.8  # above this no is high-multicollinearity risk
multicol_pairs = correlation_matrix[(correlation_matrix > threshold) & (correlation_matrix != 1.0)].stack().reset_index()
multicol_pairs.columns = ['Feature 1', 'Feature 2', 'Correlation']
print("Highly Correlated Features (Threshold > 0.8):")
print(multicol_pairs)
# Out:
# Highly Correlated Features (Threshold > 0.8):
#          Feature 1       Feature 2  Correlation
# 0          airbags  turning_radius     0.810820
# 1          airbags          length     0.809094
# 2          airbags    gross_weight     0.828988
# 3     displacement        cylinder     0.866231
# 4     displacement  turning_radius     0.875407
# 5     displacement          length     0.961655
# 6     displacement           width     0.899302
# 7     displacement     ncap_rating     0.847065
# 8         cylinder    displacement     0.866231
# 9         cylinder          length     0.805476
# 10        cylinder           width     0.862430
# 11  turning_radius         airbags     0.810820
# 12  turning_radius    displacement     0.875407
# 13  turning_radius          length     0.944899
# 14  turning_radius           width     0.825603
# 15  turning_radius    gross_weight     0.823097
# 16          length         airbags     0.809094
# 17          length    displacement     0.961655
# 18          length        cylinder     0.805476
# 19          length  turning_radius     0.944899
# 20          length           width     0.915918
# 21          length    gross_weight     0.861723
# 22           width    displacement     0.899302
# 23           width        cylinder     0.862430
# 24           width  turning_radius     0.825603
# 25           width          length     0.915918
# 26    gross_weight         airbags     0.828988
# 27    gross_weight  turning_radius     0.823097
# 28    gross_weight          length     0.861723
# 29     ncap_rating    displacement     0.847065

# %% [markdown]
# Since there is some correlation between parameter, we will feature-engineered the parameter
# 1. Consolidate Size-Related Features : Turning_radius, length, width, gross_weight into vehicle_size
#    [Vehicle_Size] = [length]*[width]*[gross_weight]
# 2. Drop [cylinder] and retain [displacement]
# 3. Keep [turning_radius, ncap_rating, airbags] as is

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

data_new = data_copy
data_new['vehicle_size'] = data_copy['length'] * data_copy['width'] * data_copy['gross_weight']
data_new = data_new.drop(columns=['length', 'width', 'gross_weight', 'cylinder'])

# %%
X = data_new.drop(columns=['claim_status'])
y = data_new['claim_status']

# Apply StandardScaler to the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # Scaled features
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Split scaled data
X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)

# Create unscaled versions of training and test sets for future analysis
X_train, X_test, y_train, y_testd = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Step 1: Feature Selection, Downsampling-Upsampling, SMOTE & SMOTE-ENN

# %% [markdown]
# #### Feature-Selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.ensemble import BalancedRandomForestClassifier, RUSBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

k = 20 

selector = SelectKBest(score_func=f_classif, k=k)
X_train_FS = selector.fit_transform(X_train_scaled, y_train)
X_test_FS = selector.transform(X_test_scaled)

selected_features = X_train.columns[selector.get_support()]

print("Selected Features:", selected_features)
print("Shape of X_train after feature selection:", X_train_FS.shape)
print("Shape of X_test after feature selection:", X_test_FS.shape)
# Out:
# Selected Features: Index(['subscription_length', 'vehicle_age', 'customer_age', 'region_code',
#        'region_density', 'model', 'fuel_type', 'max_torque', 'max_power',
#        'is_adjustable_steering', 'is_parking_sensors', 'displacement',
#        'steering_type', 'is_front_fog_lights', 'is_brake_assist',
#        'is_power_steering', 'is_driver_seat_height_adjustable',
#        'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert'],
#       dtype='object')
# Shape of X_train after feature selection: (41014, 20)
# Shape of X_test after feature selection: (17578, 20)

# %% [markdown]
# #### Downsampling and Upweighting

# %%
from sklearn.utils import resample

x_majority = X_train_scaled[y_train == 0]
x_minority = X_train_scaled[y_train == 1]
y_majority = y_train[y_train == 0]
y_minority = y_train[y_train == 1]

X_majority_downsampled, y_majority_downsampled = resample(
    x_majority, y_majority, replace=False,  
    n_samples=len(x_minority),  
    random_state=42 
)

X_train_DU = pd.concat([X_majority_downsampled, x_minority])
y_train_DU = pd.concat([y_majority_downsampled, y_minority])

class_weight_DU = {0: len(x_majority) / len(x_minority), 1: 1} # assign more weight to downsampled class

print("Shapes of downsampled data:", X_train_DU.shape, y_train_DU.shape)
print("Class weights:", class_weight_DU)
# Out:
# Shapes of downsampled data: (5208, 36) (5208,)
# Class weights: {0: 14.750384024577572, 1: 1}

# %% [markdown]
# #### SMOTE

# %%
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN

smote = SMOTE(random_state=42)
smote_enn = SMOTEENN(random_state=42)

# Apply SMOTE
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# %% [markdown]
# ## Step 2 : Algorithm-Level Approach

# %% [markdown]
# #### 1. Random Forest with Class Weights

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, make_scorer, f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# Define parameter grid
param_grid = {
    'n_estimators': [200, 300],
    'max_depth': [10, 15],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [2, 4],
    'class_weight': [{0: 1, 1: w} for w in [15, 20]],
    'criterion': ['gini', 'entropy'],
    'max_features': ['sqrt', 'log2']
}

# Scoring metric
f1_scorer = make_scorer(f1_score, pos_label=1)

# Function to train and evaluate model
def train_and_evaluate_rf(X_train, y_train, X_test, y_test, method_name):
    print(f"\nTraining Random Forest with {method_name}...")
    
    rf = RandomForestClassifier(random_state=42)
    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, scoring=f1_scorer, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_rf = grid_search.best_estimator_
    y_pred = best_rf.predict(X_test)
    y_proba = best_rf.predict_proba(X_test)[:, 1]
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_rf

# %%
# Baseline Model (No Data-Level Approach)
best_rf_baseline = train_and_evaluate_rf(X_train, y_train, X_test, y_test, "No Data-Level Approach")
# Out:
# Training Random Forest with No Data-Level Approach...
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
#
# No Data-Level Approach - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.66      0.78     16434
#        Claim       0.10      0.54      0.17      1144
#
#     accuracy                           0.65     17578
#    macro avg       0.53      0.60      0.47     17578
# weighted avg       0.90      0.65      0.74     17578
#
# AUC-ROC Score (No Data-Level Approach): 0.6468656997134544
# ----------------------------------------------------------

# %%
# Model with SMOTE
X_train_smote_unscaled, y_train_smote_unscaled = smote.fit_resample(X_train, y_train)

best_rf_smote = train_and_evaluate_rf(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE")
# Out:
# Training Random Forest with SMOTE...
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# C:\Users\maver\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# SMOTE - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.36      0.52     16434
#        Claim       0.08      0.78      0.14      1144
#
#     accuracy                           0.39     17578
#    macro avg       0.52      0.57      0.33     17578
# weighted avg       0.90      0.39      0.50     17578
#
# AUC-ROC Score (SMOTE): 0.6044923761585865
# ----------------------------------------------------------

# %% [markdown]
# #### 2. Balanced Random Forest

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

param_grid = {
    'n_estimators': [200, 300, 500, 1000],
    'max_depth': [None, 20, 30, 50],
    'min_samples_split': [5, 10,15],
    'min_samples_leaf': [2, 4, 6],
    'sampling_strategy': ['all', 0.8, 0.6],
}
param_grid_smote = {
    'n_estimators': [200, 300, 500, 1000],
    'max_depth': [None, 20, 30, 50],
    'min_samples_split': [5, 10,15],
    'min_samples_leaf': [2, 4, 6]
}

def performance_brf(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating Balanced Random Forest with {method_name}...")

    param_grid_selected = param_grid_smote if smote else param_grid
    brf = BalancedRandomForestClassifier(random_state=42)
    
    grid_search = RandomizedSearchCV(
        estimator=brf,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    
    best_brf = grid_search.best_estimator_
    y_pred = best_brf.predict(X_test)
    y_proba = best_brf.predict_proba(X_test)[:, 1]
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_brf

# %%
# Original dataset
performance_brf(X_train, y_train, X_test, y_test, "Original Dataset")
# SMOTE dataset
performance_brf(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE", smote=True)
# Out:
# Evaluating Balanced Random Forest with Original Dataset...
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# C:\Users\maver\anaconda3\Lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# C:\Users\maver\anaconda3\Lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.70      0.81     16434
#        Claim       0.10      0.49      0.17      1144
#
#     accuracy                           0.69     17578
#    macro avg       0.53      0.59      0.49     17578
# weighted avg       0.90      0.69      0.76     17578
#
# AUC-ROC Score (Original Dataset): 0.6498801680551406
# ----------------------------------------------------------
#
# Evaluating Balanced Random Forest with SMOTE...
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# C:\Users\maver\anaconda3\Lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# C:\Users\maver\anaconda3\Lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# C:\Users\maver\anaconda3\Lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# SMOTE - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.94      0.88      0.91     16434
#        Claim       0.09      0.18      0.12      1144
#
#     accuracy                           0.83     17578
#    macro avg       0.52      0.53      0.52     17578
# weighted avg       0.88      0.83      0.86     17578
#
# AUC-ROC Score (SMOTE): 0.6007429803979639
# ----------------------------------------------------------
# BalancedRandomForestClassifier(max_depth=50, min_samples_leaf=2,
#                                min_samples_split=5, n_estimators=300,
#                                random_state=42)

# %% [markdown]
# #### 3. Easy Ensemble Classifier

# %%
from imblearn.ensemble import EasyEnsembleClassifier

param_grid = {
    'n_estimators': [30, 50, 100],       
    'sampling_strategy': ['auto', 0.8, 0.6], 
    'replacement': [True, False]    #base_estimator = decisiontree   
}

def performance_easy_ensemble(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating EasyEnsembleClassifier with {method_name}...")
    
    easy_ensemble = EasyEnsembleClassifier(random_state=42)
    grid_search = GridSearchCV(
        estimator=easy_ensemble,
        param_grid=param_grid,
        scoring=f1_scorer,
        cv=5,
        verbose=2,
        n_jobs=-1
    )
    
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    print(f"Best Parameters ({method_name}):", best_params)
    print(f"Best F1-Score ({method_name}):", grid_search.best_score_)
    
    # Predict and evaluate
    y_pred = best_model.predict(X_test)
    y_proba = best_model.predict_proba(X_test)[:, 1]
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_model

# Performance Measure using original data
performance_easy_ensemble(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating EasyEnsembleClassifier with Original Dataset...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters (Original Dataset): {'n_estimators': 100, 'replacement': False, 'sampling_strategy': 0.8}
# Best F1-Score (Original Dataset): 0.1609419047908501
#
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.67      0.79     16434
#        Claim       0.10      0.50      0.16      1144
#
#     accuracy                           0.66     17578
#    macro avg       0.52      0.59      0.47     17578
# weighted avg       0.90      0.66      0.75     17578
#
# AUC-ROC Score (Original Dataset): 0.6291359813060251
# ----------------------------------------------------------
# EasyEnsembleClassifier(n_estimators=100, random_state=42, sampling_strategy=0.8)

# %% [markdown]
# #### 4. Gradient Boosting Method (XGBoost/LightBoost/Catboost)

# %% [markdown]
# ##### a. XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import precision_recall_curve
import numpy as np

param_grid_xgb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'scale_pos_weight': [14.36, 10, 20],
    'gamma': [0, 1, 5],
    'subsample': [0.8, 1.0]
}

param_grid_xgb_smote = {
    'n_estimators': [200, 300],
    'learning_rate': [0.005, 0.01, 0.05],
    'max_depth': [3, 5],
    'gamma': [1, 3, 5],
    'min_child_weight': [1, 3],
    'subsample': [0.8],
    'colsample_bytree': [0.7, 0.8],
}

def performance_xgb(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating XGBoost with {method_name}...")

    param_grid_selected = param_grid_xgb_smote if smote else param_grid_xgb
    xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
    grid_search = RandomizedSearchCV(
        estimator=xgb,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_xgb = grid_search.best_estimator_
    y_proba = best_xgb.predict_proba(X_test)[:, 1]

    # Evaluate thresholds
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)
    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5) # since our threshold result is quite low, we set a limitation to not use low threshold
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]
    f1_scores = 2 * (precision * recall) / (precision + recall)
    
    # Find the threshold with the best F1-score
    optimal_idx = np.argmax(f1_scores)
    optimal_threshold = thresholds[optimal_idx]

    print(f"\n{method_name} - Best Threshold for F1-Score: {optimal_threshold:.2f}")
    print(f"Precision: {precision[optimal_idx]:.2f}, Recall: {recall[optimal_idx]:.2f}, F1-Score: {f1_scores[optimal_idx]:.2f}")

    # Apply optimal threshold
    y_pred_threshold = (y_proba >= optimal_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report at Optimal Threshold:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_xgb

# %%
# Original dataset
performance_xgb(X_train, y_train, X_test, y_test, "Original Dataset")
# ]SMOTE dataset
performance_xgb(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE", smote=True)
# Out:
# Evaluating XGBoost with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:23:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Original Dataset - Best Threshold for F1-Score: 0.50
# Precision: 0.11, Recall: 0.38, F1-Score: 0.17
#
# Original Dataset - Classification Report at Optimal Threshold:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.79      0.86     16434
#        Claim       0.11      0.38      0.17      1144
#
#     accuracy                           0.76     17578
#    macro avg       0.53      0.59      0.52     17578
# weighted avg       0.89      0.76      0.82     17578
#
# AUC-ROC Score (Original Dataset): 0.6518995828620692
# ----------------------------------------------------------
#
# Evaluating XGBoost with SMOTE...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:27:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# SMOTE - Best Threshold for F1-Score: 0.25
# Precision: 0.10, Recall: 0.51, F1-Score: 0.17
#
# SMOTE - Classification Report at Optimal Threshold:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.69      0.80     16434
#        Claim       0.10      0.51      0.17      1144
#
#     accuracy                           0.68     17578
#    macro avg       0.53      0.60      0.48     17578
# weighted avg       0.90      0.68      0.76     17578
#
# AUC-ROC Score (SMOTE): 0.6396584430538428
# ----------------------------------------------------------
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
def performance_xgb_2(X_train, y_train, X_test, y_test, method_name, smote=False): #different threshold
    print(f"\nEvaluating XGBoost with {method_name}...")

    param_grid_selected = param_grid_xgb_smote if smote else param_grid_xgb
    xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
    grid_search = RandomizedSearchCV(
        estimator=xgb,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_lgbm = grid_search.best_estimator_
    y_proba = best_lgbm.predict_proba(X_test)[:, 1]
    threshold = 0.2  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_lgbm

# %%
# Original dataset
performance_xgb_2(X_train, y_train, X_test, y_test, "Original Dataset")
# SMOTE dataset
performance_xgb_2(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE", smote=True)
# Out:
# Evaluating XGBoost with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:21:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.98      0.13      0.24     16434
#        Claim       0.07      0.95      0.13      1144
#
#     accuracy                           0.19     17578
#    macro avg       0.52      0.54      0.18     17578
# weighted avg       0.92      0.19      0.23     17578
#
# AUC-ROC Score (Original Dataset): 0.6518995828620692
# ----------------------------------------------------------
#
# Evaluating XGBoost with SMOTE...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:25:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# SMOTE - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.52      0.68     16434
#        Claim       0.09      0.68      0.16      1144
#
#     accuracy                           0.53     17578
#    macro avg       0.52      0.60      0.42     17578
# weighted avg       0.90      0.53      0.64     17578
#
# AUC-ROC Score (SMOTE): 0.6400373692268544
# ----------------------------------------------------------
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=3, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
def performance_xgb_3(X_train, y_train, X_test, y_test, method_name, smote=False): #different threshold
    print(f"\nEvaluating XGBoost with {method_name}...")

    param_grid_selected = param_grid_xgb_smote if smote else param_grid_xgb
    xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
    grid_search = RandomizedSearchCV(
        estimator=xgb,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_lgbm = grid_search.best_estimator_
    y_proba = best_lgbm.predict_proba(X_test)[:, 1]
    threshold = 0.4  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_lgbm

# %%
# Original dataset
performance_xgb_3(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating XGBoost with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [14:34:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.55      0.70     16434
#        Claim       0.09      0.67      0.17      1144
#
#     accuracy                           0.56     17578
#    macro avg       0.53      0.61      0.43     17578
# weighted avg       0.90      0.56      0.67     17578
#
# AUC-ROC Score (Original Dataset): 0.6518995828620692
# ----------------------------------------------------------
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=1, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ##### b. LightBGM

# %%
from lightgbm import LGBMClassifier

param_grid_lgbm = {
    'n_estimators': [100, 200, 300],               
    'learning_rate': [0.005, 0.01, 0.1],           
    'max_depth': [5, 10, 15],                     
    'class_weight': [
        {0: 1, 1: 10},                             
        {0: 1, 1: 15},                             
        {0: 1, 1: 20},
    ],
    'min_child_samples': [10, 20, 40],            
    'subsample': [0.6, 0.8, 1.0],                 
    'colsample_bytree': [0.6, 0.8, 1.0],        
    'num_leaves': [31, 63, 127],                 
    'boosting_type': ['gbdt', 'dart'],            
    'lambda_l1': [0, 0.1, 1.0],                   
    'lambda_l2': [0, 0.1, 1.0],                  
    'max_bin': [255, 512],                       
    'min_split_gain': [0, 0.1, 0.5]             
}

param_grid_lgbm_smote = {
    'n_estimators': [100, 200, 300],              
    'learning_rate': [0.005, 0.01, 0.1],        
    'max_depth': [5, 10, 15],                    
    'min_child_samples': [10, 20, 40],           
    'subsample': [0.6, 0.8, 1.0],               
    'colsample_bytree': [0.6, 0.8, 1.0],        
    'num_leaves': [31, 63, 127],                 
    'boosting_type': ['gbdt', 'dart'],          
    'lambda_l1': [0, 0.1, 1.0],                
    'lambda_l2': [0, 0.1, 1.0],                
    'max_bin': [255, 512],                     
    'min_split_gain': [0, 0.1, 0.5]             
}

def performance_lgbm(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating LightGBM with {method_name}...")
    
    param_grid_selected = param_grid_lgbm_smote if smote else param_grid_lgbm
    lgbm = LGBMClassifier(random_state=42)
    grid_search =RandomizedSearchCV(
        estimator=lgbm,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_lgbm = grid_search.best_estimator_
    y_proba = best_lgbm.predict_proba(X_test)[:, 1]
    
    # Evaluate thresholds
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)
    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]
    f1_scores = 2 * (precision * recall) / (precision + recall+ 1e-09)
    
    # Find the threshold with the best F1-score
    optimal_idx = np.argmax(f1_scores)
    optimal_threshold = thresholds[optimal_idx]

    print(f"\n{method_name} - Best Threshold: {optimal_threshold:.2f}")
    print(f"Precision: {precision[optimal_idx]:.2f}, Recall: {recall[optimal_idx]:.2f}, F1-Score: {f1_scores[optimal_idx]:.2f}")

    # Apply the optimal threshold
    y_pred_threshold = (y_proba >= optimal_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report at Optimal Threshold:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_lgbm

# %%
# Original dataset
performance_lgbm(X_train, y_train, X_test, y_test, "Original Dataset")
# SMOTE dataset
performance_lgbm(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE", smote=True)
# Out:
# Evaluating LightGBM with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Number of positive: 2604, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004073 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 41014, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.404034 -> initscore=-0.388684
# [LightGBM] [Info] Start training from score -0.388684
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
#
# Original Dataset - Best Threshold: 0.48
# Precision: 0.11, Recall: 0.41, F1-Score: 0.17
#
# Original Dataset - Classification Report at Optimal Threshold:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.77      0.85     16434
#        Claim       0.11      0.41      0.17      1144
#
#     accuracy                           0.74     17578
#    macro avg       0.53      0.59      0.51     17578
# weighted avg       0.89      0.74      0.80     17578
#
# AUC-ROC Score (Original Dataset): 0.6482262755195395
# ----------------------------------------------------------
#
# Evaluating LightGBM with SMOTE...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Info] Number of positive: 38410, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005420 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1728
# [LightGBM] [Info] Number of data points in the train set: 76820, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] lambda_l2 is set=1.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.0
#
# SMOTE - Best Threshold: 0.10
# Precision: 0.09, Recall: 0.41, F1-Score: 0.15
#
# SMOTE - Classification Report at Optimal Threshold:
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.72      0.82     16434
#        Claim       0.09      0.41      0.15      1144
#
#     accuracy                           0.70     17578
#    macro avg       0.52      0.57      0.49     17578
# weighted avg       0.89      0.70      0.78     17578
#
# AUC-ROC Score (SMOTE): 0.6071748585781992
# ----------------------------------------------------------
# LGBMClassifier(colsample_bytree=0.6, lambda_l1=0, lambda_l2=1.0, max_bin=512,
#                max_depth=15, min_child_samples=10, min_split_gain=0,
#                n_estimators=300, num_leaves=127, random_state=42,
#                subsample=0.6)

# %%
def performance_lgbm_2(X_train, y_train, X_test, y_test, method_name, smote=False): #different threshold
    print(f"\nEvaluating LightGBM with {method_name}...")

    param_grid_selected = param_grid_lgbm_smote if smote else param_grid_lgbm
    lgbm = LGBMClassifier(random_state=42)
    grid_search =RandomizedSearchCV(
        estimator=lgbm,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_lgbm = grid_search.best_estimator_
    y_proba = best_lgbm.predict_proba(X_test)[:, 1]
    threshold = 0.4  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_lgbm

# %%
# Original dataset
performance_lgbm_2(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating LightGBM with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Info] Number of positive: 2604, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002878 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 41014, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.404034 -> initscore=-0.388684
# [LightGBM] [Info] Start training from score -0.388684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] lambda_l1 is set=1.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.0
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
#
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.55      0.70     16434
#        Claim       0.09      0.67      0.16      1144
#
#     accuracy                           0.55     17578
#    macro avg       0.53      0.61      0.43     17578
# weighted avg       0.90      0.55      0.66     17578
#
# AUC-ROC Score (Original Dataset): 0.6501828728348444
# ----------------------------------------------------------
# LGBMClassifier(class_weight={0: 1, 1: 10}, colsample_bytree=0.6, lambda_l1=1.0,
#                lambda_l2=0.1, learning_rate=0.01, max_bin=512, max_depth=5,
#                min_child_samples=10, min_split_gain=0, n_estimators=300,
#                random_state=42, subsample=0.6)

# %%
def performance_lgbm_3(X_train, y_train, X_test, y_test, method_name, smote=False): #different threshold
    print(f"\nEvaluating LightGBM with {method_name}...")

    param_grid_selected = param_grid_lgbm_smote if smote else param_grid_lgbm
    lgbm = LGBMClassifier(random_state=42)
    grid_search =RandomizedSearchCV(
        estimator=lgbm,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_lgbm = grid_search.best_estimator_
    y_proba = best_lgbm.predict_proba(X_test)[:, 1]
    threshold = 0.05  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)
    
    print(f"\n{method_name} - Classification Report:")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    return best_lgbm

# %%
# Original dataset
performance_lgbm_3(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "Original Dataset", smote=True)
# Out:
# Evaluating LightGBM with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
# [LightGBM] [Info] Number of positive: 38410, number of negative: 38410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1728
# [LightGBM] [Info] Number of data points in the train set: 76820, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] lambda_l1 is set=0.1, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1
# [LightGBM] [Warning] lambda_l2 is set=0.1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.1
#
# Original Dataset - Classification Report:
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.31      0.47     16434
#        Claim       0.08      0.82      0.14      1144
#
#     accuracy                           0.35     17578
#    macro avg       0.52      0.57      0.31     17578
# weighted avg       0.90      0.35      0.45     17578
#
# AUC-ROC Score (Original Dataset): 0.6157380103163236
# ----------------------------------------------------------
# LGBMClassifier(colsample_bytree=0.6, lambda_l1=0.1, lambda_l2=0.1, max_bin=512,
#                max_depth=10, min_child_samples=40, min_split_gain=0,
#                n_estimators=200, num_leaves=127, random_state=42,
#                subsample=0.8)

# %% [markdown]
# ##### c. CatBoost

# %%
from catboost import CatBoostClassifier

param_grid_catboost = {
    'iterations': [300, 500, 700],
    'depth': [7, 9, 12], 
    'learning_rate': [0.01, 0.03, 0.1], 
    'class_weights': [
        [1, 10], [1, 14.36], [1, 20], [1, 25]
    ],
    'l2_leaf_reg': [1, 3, 10],
    'border_count': [128, 256, 512],
    'subsample': [0.6, 0.8],
    'bagging_temperature': [0.0, 0.1, 0.5], 
    'random_strength': [1, 5, 10]
}

param_grid_catboost_smote = {
    'iterations': [300, 500, 700],
    'depth': [7, 9, 12], 
    'learning_rate': [0.01, 0.03, 0.1], 
    'l2_leaf_reg': [1, 3, 10],
    'border_count': [128, 256, 512],  
    'subsample': [0.6, 0.8],
    'bagging_temperature': [0.0, 0.1, 0.5], 
    'random_strength': [1, 5, 10] 
}

def performance_catboost(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating CatBoost with {method_name}...")

    param_grid_selected = param_grid_catboost_smote if smote else param_grid_catboost
    catboost = CatBoostClassifier(random_state=42, verbose=0)
    
    grid_search =RandomizedSearchCV(
        estimator=catboost,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_catboost = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    y_proba = best_catboost.predict_proba(X_test)[:, 1]
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    # Ensure valid thresholds
    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]
    
    # Compute F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_catboost, best_threshold

# %%
# Original dataset
performance_catboost(X_train, y_train, X_test, y_test, "Original Dataset")
# SMOTE dataset
performance_catboost(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE Dataset",smote=True)
# Out:
# Evaluating CatBoost with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'subsample': 0.8, 'random_strength': 1, 'learning_rate': 0.01, 'l2_leaf_reg': 10, 'iterations': 300, 'depth': 7, 'class_weights': [1, 10], 'border_count': 256, 'bagging_temperature': 0.0}
#
# Best Threshold: 0.44
# Best F1-Score: 0.1749
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.64      0.77     16434
#        Claim       0.10      0.58      0.17      1144
#
#     accuracy                           0.64     17578
#    macro avg       0.53      0.61      0.47     17578
# weighted avg       0.90      0.64      0.73     17578
#
# AUC-ROC Score (Original Dataset): 0.6546460795502416
# ----------------------------------------------------------
#
# Evaluating CatBoost with SMOTE Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'subsample': 0.6, 'random_strength': 1, 'learning_rate': 0.1, 'l2_leaf_reg': 1, 'iterations': 700, 'depth': 12, 'border_count': 512, 'bagging_temperature': 0.5}
#
# Best Threshold: 0.11
# Best F1-Score: 0.1448
#
# SMOTE Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.94      0.81      0.87     16434
#        Claim       0.10      0.29      0.14      1144
#
#     accuracy                           0.77     17578
#    macro avg       0.52      0.55      0.51     17578
# weighted avg       0.89      0.77      0.82     17578
#
# AUC-ROC Score (SMOTE Dataset): 0.5927660897882695
# ----------------------------------------------------------
# (<catboost.core.CatBoostClassifier at 0x23b17c006e0>, 0.10612698959509932)

# %%
def performance_catboost_2(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating CatBoost with {method_name}...")

    param_grid_selected = param_grid_catboost_smote if smote else param_grid_catboost
    catboost = CatBoostClassifier(random_state=42, verbose=0)
    
    grid_search =RandomizedSearchCV(
        estimator=catboost,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_cat = grid_search.best_estimator_
    y_proba = best_cat.predict_proba(X_test)[:, 1]
    threshold = 0.42  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_cat

# %%
# Original dataset
performance_catboost_2(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating CatBoost with Original Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.97      0.47      0.63     16434
#        Claim       0.09      0.76      0.16      1144
#
#     accuracy                           0.49     17578
#    macro avg       0.53      0.61      0.40     17578
# weighted avg       0.91      0.49      0.60     17578
#
# AUC-ROC Score (Original Dataset): 0.6453344103261957
# ----------------------------------------------------------

# %%
def performance_catboost_3(X_train, y_train, X_test, y_test, method_name, smote=False):
    print(f"\nEvaluating CatBoost with {method_name}...")

    param_grid_selected = param_grid_catboost_smote if smote else param_grid_catboost
    catboost = CatBoostClassifier(random_state=42, verbose=0)
    
    grid_search =RandomizedSearchCV(
        estimator=catboost,
        param_distributions=param_grid_selected,
        scoring=f1_scorer,
        cv=5,
        n_jobs=-1,
        n_iter=100,
        verbose=2
    )
    
    grid_search.fit(X_train, y_train)
    best_cat = grid_search.best_estimator_
    y_proba = best_cat.predict_proba(X_test)[:, 1]
    threshold = 0.04  # Adjust to increase recall
    y_pred_threshold = (y_proba >= threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_cat

# %%
# SMOTE dataset
performance_catboost_3(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE Dataset",smote=True)
# Out:
# Evaluating CatBoost with SMOTE Dataset...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# SMOTE Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.55      0.70     16434
#        Claim       0.08      0.60      0.15      1144
#
#     accuracy                           0.55     17578
#    macro avg       0.52      0.57      0.42     17578
# weighted avg       0.90      0.55      0.66     17578
#
# AUC-ROC Score (SMOTE Dataset): 0.5962404130188905
# ----------------------------------------------------------

# %% [markdown]
# #### 5. Stacked Ensemble With/Without Class Weight

# %%
# the previous model is retrained due to error
param_grid_stacked = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [5, 10],
    'rf__class_weight': [{0: 1, 1: 14.36}, {0: 1, 1: 20}],
    'rf__min_samples_split': [2, 10],
    'rf__min_samples_leaf': [1, 5],
    'gb__n_estimators': [100, 200],
    'gb__learning_rate': [0.01, 0.05],
    'gb__max_depth': [3, 5],
    'gb__subsample': [0.6, 0.8],
    'final_estimator__scale_pos_weight': [10, 14.36, 20]
}

def performance_stacked(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Define base models
    rf = RandomForestClassifier(random_state=42)
    gb = GradientBoostingClassifier(random_state=42)
    catboost = CatBoostClassifier(verbose=0, random_state=42)

    # Define meta-model (using CatBoost for better meta-learning)
    meta_model = CatBoostClassifier(
    random_state=42,
    verbose=0,
    eval_metric="F1",
    early_stopping_rounds=10
)

    # Stacked Ensemble
    stacking = StackingClassifier(
        estimators=[('rf', rf), ('gb', gb), ('catboost', catboost)],
        final_estimator=meta_model,
        cv=5
    )

    grid_search =RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked,
        scoring=f1_scorer,
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    # Generate probabilities
    y_proba = best_catboost.predict_proba(X_test)[:, 1]

    # Calculate Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]
    
    # Compute F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)  # Add small epsilon to avoid division by zero
    if np.isnan(f1_scores).all():
        print("\nNo valid F1-Scores found. Check the predicted probabilities and threshold logic.")
        return None, None

    # Find the threshold that maximizes F1-Score
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# Example Usage
performance_stacked(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating Stacked Ensemble with Original Dataset...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
#
# Best Parameters: {'rf__n_estimators': 100, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 5, 'rf__max_depth': 5, 'rf__class_weight': {0: 1, 1: 14.36}, 'gb__subsample': 0.6, 'gb__n_estimators': 100, 'gb__max_depth': 5, 'gb__learning_rate': 0.05, 'final_estimator__scale_pos_weight': 14.36}
#
# Best Threshold: 0.11
# Best F1-Score: 0.1540
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.73      0.82     16434
#        Claim       0.09      0.41      0.15      1144
#
#     accuracy                           0.71     17578
#    macro avg       0.52      0.57      0.49     17578
# weighted avg       0.89      0.71      0.78     17578
#
# AUC-ROC Score (Original Dataset): 0.6001375974335996
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('rf',
#                                  RandomForestClassifier(class_weight={0: 1,
#                                                                       1: 14.36},
#                                                         max_depth=5,
#                                                         min_samples_leaf=5,
#                                                         random_state=42)),
#                                 ('gb',
#                                  GradientBoostingClassifier(learning_rate=0.05,
#                                                             max_depth=5,
#                                                             random_state=42,
#                                                             subsample=0.6)),
#                                 ('catboost',
#                                  <catboost.core.CatBoostClassifier object at 0x000001390E401130>)],
#                     final_estimator=<catboost.core.CatBoostClassifier object at 0x0000013914C53500>),
#  0.1061026378098228)

# %%
param_grid_stacked = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [5, 10],
    'rf__class_weight': [{0: 1, 1: 14.36}, {0: 1, 1: 20}],
    'rf__min_samples_split': [2, 10],
    'rf__min_samples_leaf': [1, 5],
    'gb__n_estimators': [100, 200],
    'gb__learning_rate': [0.01, 0.05],
    'gb__max_depth': [3, 5],
    'gb__subsample': [0.6, 0.8],
    'final_estimator__scale_pos_weight': [10, 14.36, 20]
}

param_grid_stacked_smote = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [5, 10],
    'rf__class_weight': [{0: 1, 1: 14.36}, {0: 1, 1: 20}],
    'rf__min_samples_split': [2, 10],
    'rf__min_samples_leaf': [1, 5],
    'gb__n_estimators': [100, 200],
    'gb__learning_rate': [0.01, 0.05],
    'gb__max_depth': [3, 5],
    'gb__subsample': [0.6, 0.8],
    'final_estimator__scale_pos_weight': [10, 14.36, 20]
}

# %% [markdown]
# #### a. Model 1

# %% [markdown]
# Base Models:
# - RandomForestClassifier
# - GradientBoostingClassifier
# - LightGBM
#
# Meta-Model:
# - XGBoost

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier, StackingClassifier
import numpy as np

f1_scorer = make_scorer(f1_score, average='weighted')

def performance_stacked(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Base models
    rf = RandomForestClassifier(random_state=42)
    gb = GradientBoostingClassifier(random_state=42)
    lgb = LGBMClassifier(random_state=42)

    # Meta-Model
    meta_model = XGBClassifier(
        random_state=42,
        eval_metric='auc',
        use_label_encoder=False
    )

    # Stacking
    stacking = StackingClassifier(
        estimators=[('rf', rf), ('gb', gb), ('lgb', lgb)],
        final_estimator=meta_model,
        cv=5
    )

    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked,
        scoring=f1_scorer,
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    y_proba = best_model.predict_proba(X_test)[:, 1]
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]

    # F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Optimal Threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# %%
def performance_stacked_smote(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Base models
    rf = RandomForestClassifier(random_state=42)
    gb = GradientBoostingClassifier(random_state=42)
    lgb = LGBMClassifier(random_state=42)

    # Meta-Model
    meta_model = XGBClassifier(
        random_state=42,
        eval_metric='auc',
        use_label_encoder=False
    )

    # Stacking
    stacking = StackingClassifier(
        estimators=[('rf', rf), ('gb', gb), ('lgb', lgb)],
        final_estimator=meta_model,
        cv=5
    )

    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked_smote,
        scoring=f1_scorer,
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    y_proba = best_model.predict_proba(X_test)[:, 1]
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]

    # F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Optimal Threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# %%
performance_stacked(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating Stacked Ensemble with Original Dataset...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [LightGBM] [Info] Number of positive: 2604, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 41014, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063491 -> initscore=-2.691269
# [LightGBM] [Info] Start training from score -2.691269
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001658 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 386
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Info] Number of positive: 2084, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001594 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 386
# [LightGBM] [Info] Number of data points in the train set: 32812, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063513 -> initscore=-2.690885
# [LightGBM] [Info] Start training from score -2.690885
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:14:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'rf__n_estimators': 200, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 5, 'rf__max_depth': 10, 'rf__class_weight': {0: 1, 1: 20}, 'gb__subsample': 0.6, 'gb__n_estimators': 200, 'gb__max_depth': 3, 'gb__learning_rate': 0.01, 'final_estimator__scale_pos_weight': 10}
#
# Best Threshold: 0.37
# Best F1-Score: 0.1578
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.65      0.77     16434
#        Claim       0.09      0.51      0.16      1144
#
#     accuracy                           0.64     17578
#    macro avg       0.52      0.58      0.47     17578
# weighted avg       0.89      0.64      0.73     17578
#
# AUC-ROC Score (Original Dataset): 0.6162501776548874
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('rf',
#                                  RandomForestClassifier(class_weight={0: 1,
#                                                                       1: 20},
#                                                         max_depth=10,
#                                                         min_samples_leaf=5,
#                                                         min_samples_split=10,
#                                                         n_estimators=200,
#                                                         random_state=42)),
#                                 ('gb',
#                                  GradientBoostingClassifier(learning_rate=0.01,
#                                                             n_estimators=200,
#                                                             random_state=42,
#                                                             subsample=0.6)),
#                                 ('lgb', LGBMClassifier(random_state=42))],
#                     final_estimator=XGBClassifier(b...
#                                                   grow_policy=None,
#                                                   importance_type=None,
#                                                   interaction_constraints=None,
#                                                   learning_rate=None,
#                                                   max_bin=None,
#                                                   max_cat_threshold=None,
#                                                   max_cat_to_onehot=None,
#                                                   max_delta_step=None,
#                                                   max_depth=None,
#                                                   max_leaves=None,
#                                                   min_child_weight=None,
#                                                   missing=nan,
#                                                   monotone_constraints=None,
#                                                   multi_strategy=None,
#                                                   n_estimators=None, n_jobs=None,
#                                                   num_parallel_tree=None,
#                                                   random_state=42, ...)),
#  0.37379363)

# %%
performance_stacked_smote(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE")
# Out:
# Evaluating Stacked Ensemble with SMOTE...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [LightGBM] [Info] Number of positive: 38410, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002968 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 76820, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002997 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002958 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003467 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003852 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:11:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'rf__n_estimators': 100, 'rf__min_samples_split': 10, 'rf__min_samples_leaf': 1, 'rf__max_depth': 10, 'rf__class_weight': {0: 1, 1: 14.36}, 'gb__subsample': 0.8, 'gb__n_estimators': 200, 'gb__max_depth': 3, 'gb__learning_rate': 0.01, 'final_estimator__scale_pos_weight': 10}
#
# Best Threshold: 0.50
# Best F1-Score: 0.1485
#
# SMOTE - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.69      0.80     16434
#        Claim       0.09      0.44      0.15      1144
#
#     accuracy                           0.68     17578
#    macro avg       0.52      0.56      0.47     17578
# weighted avg       0.89      0.68      0.76     17578
#
# AUC-ROC Score (SMOTE): 0.5929799937193146
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('rf',
#                                  RandomForestClassifier(class_weight={0: 1,
#                                                                       1: 14.36},
#                                                         max_depth=10,
#                                                         min_samples_split=10,
#                                                         random_state=42)),
#                                 ('gb',
#                                  GradientBoostingClassifier(learning_rate=0.01,
#                                                             n_estimators=200,
#                                                             random_state=42,
#                                                             subsample=0.8)),
#                                 ('lgb', LGBMClassifier(random_state=42))],
#                     final_estimator=XGBClassifier(base_score=None, booster=None,
#                                                   callb...
#                                                   grow_policy=None,
#                                                   importance_type=None,
#                                                   interaction_constraints=None,
#                                                   learning_rate=None,
#                                                   max_bin=None,
#                                                   max_cat_threshold=None,
#                                                   max_cat_to_onehot=None,
#                                                   max_delta_step=None,
#                                                   max_depth=None,
#                                                   max_leaves=None,
#                                                   min_child_weight=None,
#                                                   missing=nan,
#                                                   monotone_constraints=None,
#                                                   multi_strategy=None,
#                                                   n_estimators=None, n_jobs=None,
#                                                   num_parallel_tree=None,
#                                                   random_state=42, ...)),
#  0.49843648)

# %% [markdown]
# #### b. Model 2

# %% [markdown]
# Base Models:
# - CatBoost
# - XGBoost
# - LightGBM
#
# Meta-Model:
# - Logistic Regression

# %%
param_grid_stacked = {
    'cat__learning_rate': [0.01, 0.05],
    'cat__depth': [5, 10],
    'cat__iterations': [100, 200],
    'cat__class_weights': [{0: 1, 1: 14.36}, {0: 1, 1: 20}],  # Similar to scale_pos_weight
    'xgb__learning_rate': [0.01, 0.05],
    'xgb__max_depth': [5, 10],
    'xgb__n_estimators': [100, 200],
    'xgb__scale_pos_weight': [10, 14.36, 20],  # Matches original intent
    'lgb__learning_rate': [0.01, 0.05],
    'lgb__max_depth': [5, 10],
    'lgb__n_estimators': [100, 200],
    'lgb__scale_pos_weight': [10, 14.36, 20],  # Matches original intent
    'final_estimator__C': [0.01, 0.1, 1, 10]  # Logistic Regression regularization
}

param_grid_stacked_smote = {
    'cat__learning_rate': [0.01, 0.05],
    'cat__depth': [5, 10],
    'cat__iterations': [100, 200],
    'xgb__learning_rate': [0.01, 0.05],
    'xgb__max_depth': [5, 10],
    'xgb__n_estimators': [100, 200],
    'lgb__learning_rate': [0.01, 0.05],
    'lgb__max_depth': [5, 10],
    'lgb__n_estimators': [100, 200],
    'final_estimator__C': [0.01, 0.1, 1, 10] 
}
def performance_stacked_2(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Define base models
    cat = CatBoostClassifier(random_state=42, verbose=0)
    xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="logloss")
    lgb = LGBMClassifier(random_state=42)

    # Define meta-model
    meta_model = LogisticRegression(class_weight='balanced', random_state=42, max_iter=1000)

    # Stacked Ensemble
    stacking = StackingClassifier(
        estimators=[('cat', cat), ('xgb', xgb), ('lgb', lgb)],
        final_estimator=meta_model,
        cv=5
    )

    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked,
        scoring=make_scorer(f1_score, pos_label=1),
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    # Generate probabilities
    y_proba = best_model.predict_proba(X_test)[:, 1]

    # Calculate Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    # Compute F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# %%
def performance_stacked_smote_2(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Define base models
    cat = CatBoostClassifier(random_state=42, verbose=0)
    xgb = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric="logloss")
    lgb = LGBMClassifier(random_state=42)

    # Define meta-model
    meta_model = LogisticRegression(class_weight='balanced', random_state=42, max_iter=1000)

    # Stacked Ensemble
    stacking = StackingClassifier(
        estimators=[('cat', cat), ('xgb', xgb), ('lgb', lgb)],
        final_estimator=meta_model,
        cv=5
    )

    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked_smote,
        scoring=make_scorer(f1_score, pos_label=1),
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    # Generate probabilities
    y_proba = best_model.predict_proba(X_test)[:, 1]

    # Calculate Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    # Compute F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# %%
performance_stacked_2(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating Stacked Ensemble with Original Dataset...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 2604, number of negative: 38410
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002781 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 41014, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063491 -> initscore=-2.691269
# [LightGBM] [Info] Start training from score -2.691269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [18:54:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002758 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002380 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 385
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2083, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002747 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 386
# [LightGBM] [Info] Number of data points in the train set: 32811, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063485 -> initscore=-2.691365
# [LightGBM] [Info] Start training from score -2.691365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2084, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002787 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 386
# [LightGBM] [Info] Number of data points in the train set: 32812, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.063513 -> initscore=-2.690885
# [LightGBM] [Info] Start training from score -2.690885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Best Parameters: {'xgb__scale_pos_weight': 14.36, 'xgb__n_estimators': 100, 'xgb__max_depth': 10, 'xgb__learning_rate': 0.05, 'lgb__scale_pos_weight': 14.36, 'lgb__n_estimators': 200, 'lgb__max_depth': 5, 'lgb__learning_rate': 0.01, 'final_estimator__C': 0.1, 'cat__learning_rate': 0.05, 'cat__iterations': 200, 'cat__depth': 5, 'cat__class_weights': {0: 1, 1: 14.36}}
#
# Best Threshold: 0.55
# Best F1-Score: 0.1740
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.67      0.79     16434
#        Claim       0.10      0.55      0.17      1144
#
#     accuracy                           0.66     17578
#    macro avg       0.53      0.61      0.48     17578
# weighted avg       0.90      0.66      0.75     17578
#
# AUC-ROC Score (Original Dataset): 0.6532171544835838
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('cat',
#                                  <catboost.core.CatBoostClassifier object at 0x000001D5AB0D2780>),
#                                 ('xgb',
#                                  XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=None,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None, gamma=No...
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=100, n_jobs=None,
#                                                num_parallel_tree=None,
#                                                random_state=42, ...)),
#                                 ('lgb',
#                                  LGBMClassifier(learning_rate=0.01, max_depth=5,
#                                                 n_estimators=200,
#                                                 random_state=42,
#                                                 scale_pos_weight=14.36))],
#                     final_estimator=LogisticRegression(C=0.1,
#                                                        class_weight='balanced',
#                                                        max_iter=1000,
#                                                        random_state=42)),
#  0.5519099234203826)

# %%
performance_stacked_smote_2(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE")
# Out:
# Evaluating Stacked Ensemble with SMOTE...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:42:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 38410, number of negative: 38410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006455 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 76820, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:42:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:43:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:43:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:43:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\maver\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:43:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003357 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003273 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003707 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003565 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Best Parameters: {'xgb__n_estimators': 200, 'xgb__max_depth': 10, 'xgb__learning_rate': 0.05, 'lgb__n_estimators': 100, 'lgb__max_depth': 5, 'lgb__learning_rate': 0.01, 'final_estimator__C': 1, 'cat__learning_rate': 0.05, 'cat__iterations': 100, 'cat__depth': 10}
#
# Best Threshold: 0.10
# Best F1-Score: 0.1644
#
# SMOTE - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.69      0.80     16434
#        Claim       0.10      0.49      0.16      1144
#
#     accuracy                           0.68     17578
#    macro avg       0.52      0.59      0.48     17578
# weighted avg       0.90      0.68      0.76     17578
#
# AUC-ROC Score (SMOTE): 0.6290367552005011
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('cat',
#                                  <catboost.core.CatBoostClassifier object at 0x000001D5ABECEC00>),
#                                 ('xgb',
#                                  XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=None,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None, gamma=No...
#                                                max_delta_step=None, max_depth=10,
#                                                max_leaves=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=200, n_jobs=None,
#                                                num_parallel_tree=None,
#                                                random_state=42, ...)),
#                                 ('lgb',
#                                  LGBMClassifier(learning_rate=0.01, max_depth=5,
#                                                 random_state=42))],
#                     final_estimator=LogisticRegression(C=1,
#                                                        class_weight='balanced',
#                                                        max_iter=1000,
#                                                        random_state=42)),
#  0.10473689850545928)

# %% [markdown]
# #### c. Model 3

# %% [markdown]
# Base Models:
# - RandomForestClassifier
# - GradientBoostingClassifier
# - LightGBM
#
# Meta-Model:
# - CatBoost

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score, classification_report, precision_recall_curve, make_scorer
import numpy as np

# Parameter grid
param_grid_stacked = {
    'rf__n_estimators': [100, 200, 300],
    'rf__max_depth': [5, 10, 15],
    'rf__min_samples_split': [2, 5, 10],
    'gb__learning_rate': [0.01, 0.05, 0.1],
    'gb__n_estimators': [100, 200],
    'gb__max_depth': [3, 5, 7],
    'lgb__learning_rate': [0.01, 0.05],
    'lgb__n_estimators': [100, 200],
    'lgb__max_depth': [5, 10],
    'final_estimator__depth': [4, 6, 8],  # Meta-model: CatBoostClassifier depth
    'final_estimator__learning_rate': [0.01, 0.05, 0.1]
}

def performance_stacked_rf_gb_lgb(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")
    
    # Define base models
    rf = RandomForestClassifier(random_state=42)
    gb = GradientBoostingClassifier(random_state=42)
    lgb = LGBMClassifier(random_state=42, verbose=-1)
    
    # Define meta-model
    meta_model = CatBoostClassifier(
        random_state=42, verbose=0
    )  # CatBoost as final meta-model
    
    # Stacked Ensemble
    stacking = StackingClassifier(
        estimators=[
            ('rf', rf),
            ('gb', gb),
            ('lgb', lgb)
        ],
        final_estimator=meta_model,
        cv=5
    )
    
    # Grid search with RandomizedSearchCV
    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked,
        scoring=make_scorer(f1_score, pos_label=1),
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )
    
    # Fit the model
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)
    
    # Generate probabilities
    y_proba = best_model.predict_proba(X_test)[:, 1]
    
    # Precision-Recall curve and threshold optimization
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")
    
    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)
    
    # Final report
    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")
    
    return best_model, best_threshold

# %%
best_model, best_threshold = performance_stacked_3(X_train, y_train, X_test, y_test, "RandomForest-GB-LGB with CatBoost Meta-Model")
# Out:
# Evaluating Stacked Ensemble with RandomForest-GB-LGB with CatBoost Meta-Model...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
#
# Best Parameters: {'rf__n_estimators': 300, 'rf__min_samples_split': 10, 'rf__max_depth': 5, 'lgb__n_estimators': 100, 'lgb__max_depth': 10, 'lgb__learning_rate': 0.01, 'gb__n_estimators': 100, 'gb__max_depth': 5, 'gb__learning_rate': 0.05, 'final_estimator__learning_rate': 0.1, 'final_estimator__depth': 8}
#
# Best Threshold: 0.04
# Best F1-Score: 0.1509
#
# RandomForest-GB-LGB with CatBoost Meta-Model - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.96      0.43      0.59     16434
#        Claim       0.08      0.75      0.15      1144
#
#     accuracy                           0.45     17578
#    macro avg       0.52      0.59      0.37     17578
# weighted avg       0.90      0.45      0.56     17578
#
# AUC-ROC Score (RandomForest-GB-LGB with CatBoost Meta-Model): 0.5993916330718083
# ----------------------------------------------------------

# %%
param_grid_stacked_smote_3 = {
    'rf__n_estimators': [100, 200],
    'rf__max_depth': [5, 10],
    'rf__min_samples_split': [2, 10],
    'rf__min_samples_leaf': [1, 5],
    'gb__n_estimators': [100, 200],
    'gb__learning_rate': [0.01, 0.05],
    'gb__max_depth': [3, 5],
    'gb__subsample': [0.6, 0.8],
    'lgb__n_estimators': [100, 200],
    'lgb__learning_rate': [0.01, 0.05],
    'lgb__max_depth': [3, 5, 10],  # Allow deeper trees
    'final_estimator__depth': [5, 7, 9],
    'final_estimator__learning_rate': [0.01, 0.05]
}

def performance_stacked_smote_3(X_train, y_train, X_test, y_test, method_name):
    print(f"\nEvaluating Stacked Ensemble with {method_name}...\n")

    # Define base models
    rf = RandomForestClassifier(random_state=42)
    gb = GradientBoostingClassifier(random_state=42)
    lgb = LGBMClassifier(random_state=42, force_col_wise=True, verbose=-1)  # Optimized memory use

    # Define meta-model (CatBoost)
    meta_model = CatBoostClassifier(
        random_state=42,
        verbose=0,
        eval_metric="F1",
        early_stopping_rounds=10
    )

    # Stacked Ensemble
    stacking = StackingClassifier(
        estimators=[('rf', rf), ('gb', gb), ('lgb', lgb)],
        final_estimator=meta_model,
        cv=5
    )

    # RandomizedSearchCV for tuning
    grid_search = RandomizedSearchCV(
        estimator=stacking,
        param_distributions=param_grid_stacked_smote_3,
        scoring='f1',
        cv=StratifiedKFold(n_splits=3),
        n_jobs=-1,
        n_iter=50,
        verbose=2
    )

    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print("\nBest Parameters:", grid_search.best_params_)

    # Generate probabilities
    y_proba = best_model.predict_proba(X_test)[:, 1]

    # Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

    # Ensure valid thresholds
    valid_thresholds = (thresholds >= 0.1) & (thresholds <= 0.5)
    thresholds = thresholds[valid_thresholds]
    precision = precision[:-1][valid_thresholds]
    recall = recall[:-1][valid_thresholds]

    # Compute F1-Scores
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9)
    if len(f1_scores) == 0 or np.isnan(f1_scores).all():
        print("\nNo valid F1-Scores found. Check the predicted probabilities and threshold logic.")
        return None, None

    # Find the threshold that maximizes F1-Score
    best_index = np.argmax(f1_scores)
    best_threshold = thresholds[best_index]
    print(f"\nBest Threshold: {best_threshold:.2f}")
    print(f"Best F1-Score: {f1_scores[best_index]:.4f}")

    # Apply the optimal threshold
    y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
    auc_roc = roc_auc_score(y_test, y_proba)

    print(f"\n{method_name} - Classification Report (Best Threshold):")
    print(classification_report(y_test, y_pred_best_threshold, target_names=['No Claim', 'Claim']))
    print(f"AUC-ROC Score ({method_name}): {auc_roc}")
    print("----------------------------------------------------------")

    return best_model, best_threshold

# %%
performance_stacked_3(X_train, y_train, X_test, y_test, "Original Dataset")
# Out:
# Evaluating Stacked Ensemble with Original Dataset...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
#
# Best Parameters: {'rf__n_estimators': 200, 'rf__min_samples_split': 10, 'rf__max_depth': 15, 'lgb__n_estimators': 100, 'lgb__max_depth': 5, 'lgb__learning_rate': 0.01, 'gb__n_estimators': 100, 'gb__max_depth': 5, 'gb__learning_rate': 0.01, 'final_estimator__learning_rate': 0.1, 'final_estimator__depth': 8}
#
# Best Threshold: 0.06
# Best F1-Score: 0.1518
#
# Original Dataset - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.56      0.70     16434
#        Claim       0.09      0.60      0.15      1144
#
#     accuracy                           0.56     17578
#    macro avg       0.52      0.58      0.43     17578
# weighted avg       0.90      0.56      0.67     17578
#
# AUC-ROC Score (Original Dataset): 0.6089382429059318
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('rf',
#                                  RandomForestClassifier(max_depth=15,
#                                                         min_samples_split=10,
#                                                         n_estimators=200,
#                                                         random_state=42)),
#                                 ('gb',
#                                  GradientBoostingClassifier(learning_rate=0.01,
#                                                             max_depth=5,
#                                                             random_state=42)),
#                                 ('lgb',
#                                  LGBMClassifier(learning_rate=0.01, max_depth=5,
#                                                 random_state=42, verbose=-1))],
#                     final_estimator=<catboost.core.CatBoostClassifier object at 0x0000023B76F3B860>),
#  0.05785024710201968)

# %%
performance_stacked_smote_3(X_train_smote_unscaled, y_train_smote_unscaled, X_test, y_test, "SMOTE")
# Out:
# Evaluating Stacked Ensemble with SMOTE...
#
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 38410, number of negative: 38410
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 76820, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Total Bins 958
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Number of positive: 30728, number of negative: 30728
# [LightGBM] [Info] Total Bins 957
# [LightGBM] [Info] Number of data points in the train set: 61456, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
#
# Best Parameters: {'rf__n_estimators': 100, 'rf__min_samples_split': 2, 'rf__min_samples_leaf': 5, 'rf__max_depth': 10, 'lgb__n_estimators': 200, 'lgb__min_data_in_leaf': 50, 'lgb__max_depth': 3, 'lgb__learning_rate': 0.01, 'gb__subsample': 0.8, 'gb__n_estimators': 200, 'gb__max_depth': 5, 'gb__learning_rate': 0.05, 'final_estimator__learning_rate': 0.01, 'final_estimator__depth': 7}
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
#
# Best Threshold: 0.13
# Best F1-Score: 0.1676
#
# SMOTE - Classification Report (Best Threshold):
#               precision    recall  f1-score   support
#
#     No Claim       0.95      0.69      0.80     16434
#        Claim       0.10      0.50      0.17      1144
#
#     accuracy                           0.68     17578
#    macro avg       0.53      0.59      0.48     17578
# weighted avg       0.90      0.68      0.76     17578
#
# AUC-ROC Score (SMOTE): 0.6288215747073908
# ----------------------------------------------------------
# (StackingClassifier(cv=5,
#                     estimators=[('rf',
#                                  RandomForestClassifier(max_depth=10,
#                                                         min_samples_leaf=5,
#                                                         random_state=42)),
#                                 ('gb',
#                                  GradientBoostingClassifier(learning_rate=0.05,
#                                                             max_depth=5,
#                                                             n_estimators=200,
#                                                             random_state=42,
#                                                             subsample=0.8)),
#                                 ('lgb',
#                                  LGBMClassifier(force_col_wise=True,
#                                                 learning_rate=0.01, max_depth=3,
#                                                 min_data_in_leaf=50,
#                                                 n_estimators=200,
#                                                 random_state=42))],
#                     final_estimator=<catboost.core.CatBoostClassifier object at 0x000001D5975926F0>),
#  0.13210864109212733)

# %% [markdown]
# Focus on operational efficiency than fraud detection
#
# The most obvious damage caused by false negatives is the financial loss that can occur from the initial fraudulent transaction(s)
#
# Misclassifying a fraudulent claim as legitimate (false negative) could result in financial losses.
# Similarly, misclassifying legitimate claims as fraudulent (false positives) might lead to customer dissatisfaction and reputational damag
#
#
#
#
# 2. Data Accuracy and Adequate Business Analysis
#
#
# o add filters that only triggered deeper checks for significant changes in data
# only flagging claims over $10,000), you focus resources on cases tha to reduce unnnecessary investigation
#
#
# CPT Insurance question  When you take out a CTP insurance policy, you'll be asked questions about: Your vehicle, How it's used and where it is normally kept, Your driving history, Details of other drivers of your vehicle, and Details of any other insurance you hold
#
#
# https://www.sira.nsw.gov.au/CTP-open-data [2017 CTP Open Scheme Data]
# https://www.synectics-solutions.com/our-thinking/reducing-false-positives-in-fraud-detection-systems
#
# While the team considered both forms of error relatively benign, they deemed false positives more likely to cause harm than false negatives. So they set a high threshold of model confidence for receiving an early warning to ensure a low false positive rate.
#
#
# https://www.industry.gov.au/news/australian-ai-ethics-principles-insurance-australia-group-reviews-its-ai-claim-decisions     IAG on creating ethical artificial

# %% [markdown]
# <h1 style="font-size: 40px;">Results(3min)</h1>
